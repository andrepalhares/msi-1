# %% [markdown]
# # Visualização dos Dados

# %%
from pandas import DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('musicas_features.xlsx', usecols = "B:T")
df.dropna(subset=['id'])
df = df.drop_duplicates(subset=['id'], keep='last')
df['Ano'] = df['Ano'].astype(int)
df.head()
# Out:
#    Posicao                       Musica        Artista   Ano  \
# 0      1.0                      Balancê      Gal Costa  1980
# 1      4.0                     Momentos         Joanna  1980
# 2      5.0                Menino do Rio  Baby Consuelo  1980
# 3      6.0  Toada (Na Direção do Dia)     Boca Livre  1980
# 4      9.0               Meu Bem Querer         Djavan  1980
#
#                        id release_date  danceability  energy  key  loudness  \
# 0  2m1G38M0gJuE4aVPh0tmIP   1979-01-08         0.638   0.736  9.0   -10.536
# 1  5ncQCIFnjpHWRXbuKFG8RP   2002-11-08         0.501   0.296  7.0   -12.018
# 2  6tisytwaOaBA4CAZPPdlFP   1978-09-14         0.380   0.548  0.0    -9.260
# 3  2LO6c0rfmBm49Qs9KtQR1W   2007-01-01         0.402   0.506  6.0   -13.094
# 4  5ogHB4oYt1C7kaWJYm5MDG   1999-03-25         0.519   0.457  9.0    -8.450
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0   1.0       0.0811        0.0849          0.000000     0.333    0.881
# 1   0.0       0.0292        0.8020          0.006370     0.117    0.305
# 2   1.0       0.0333        0.7300          0.000142     0.310    0.395
# 3   0.0       0.0409        0.9280          0.000946     0.728    0.446
# 4   1.0       0.0326        0.7630          0.000666     0.796    0.264
#
#      tempo  duration_ms  time_signature
# 0  144.823     188667.0             4.0
# 1  132.462     235147.0             4.0
# 2  152.498     263733.0             4.0
# 3   97.082     233707.0             4.0
# 4   81.561     254800.0             4.0

# %%
plt.rcParams["figure.figsize"] = (30,12)

# %% [markdown]
# ## Danceability

# %%
feature = df.groupby(by='Ano').mean()['danceability'].reset_index()

# plt.plot('Ano', 'danceability', data=feature, marker='', color='red', linewidth=2)
z = np.polyfit(feature['Ano'], feature['danceability'], 1)
p = np.poly1d(z)
plt.plot(feature['Ano'],p(feature['Ano']),"g--")
plt.plot(feature['Ano'], feature['danceability'])

# %% [markdown]
# ## Duração das músicas

# %%
feature = df.groupby(by='Ano').mean()['duration_ms'].reset_index()

plt.plot('Ano', 'duration_ms', data=feature, marker='.', color='red', linewidth=2)

# %%
fig, ax = plt.subplots()

ax.hist(df[(df['Ano'] >= 1980) & (df['Ano'] < 1990)]['duration_ms'], 
        histtype="stepfilled", bins=25, alpha=0.5, density=True, label='1980s')
ax.hist(df[(df['Ano'] >= 1990) & (df['Ano'] < 2000)]['duration_ms'], 
        histtype="stepfilled", bins=25, alpha=0.5, density=True, label='1990s')
ax.hist(df[(df['Ano'] >= 2000) & (df['Ano'] < 2010)]['duration_ms'], 
        histtype="stepfilled", bins=25, alpha=0.5, density=True, label='2000s')
ax.hist(df[(df['Ano'] >= 2010) & (df['Ano'] <= 2020)]['duration_ms'], 
        histtype="stepfilled", bins=25, alpha=0.5, density=True, label='2010s')

plt.legend()
plt.show()

# %% [markdown]
# ## Batidas por minuto

# %%
sns.regplot(x=df["Ano"], y=df["tempo"], color="g")
# Out:
# <AxesSubplot:xlabel='Ano', ylabel='tempo'>

# %%
ax = sns.boxplot(x="Ano", y="tempo", data=df)

# %% [markdown]
# ## Gravações ao vivo

# %%
liveness = pd.DataFrame({'Ano': [], 'Percentual': []})

liveness['Ano'] = df.groupby(['Ano']).agg({'liveness': 'count'}).reset_index()['Ano']
liveness['Percentual'] = df[df['liveness'] > 0.8].groupby(['Ano']).agg({'liveness': 'count'}).reset_index()['liveness'] / df.groupby(['Ano']).agg({'liveness': 'count'}).reset_index()['liveness']

sns.regplot(x=liveness['Ano'], y=liveness['Percentual'], color="m")
# Out:
# <AxesSubplot:xlabel='Ano', ylabel='Percentual'>

# %% [markdown]
# ## Speechiness

# %%
speechiness = df.groupby(by='Ano').mean()['speechiness'].reset_index()

plt.plot('Ano', 'speechiness', data=speechiness, marker='.', color='green', linewidth=2)

# %% [markdown]
# ## Valence

# %%
valence = df.groupby(by='Ano').mean()['valence'].reset_index()

plt.plot('Ano', 'valence', data=valence, marker='.', color='navy', linewidth=2)

# %%
df[df['Ano'] == 1996].sort_values(by='valence', ascending=False)[['Musica', 'Artista', 'valence']]
# Out:
#                               Musica                    Artista  valence
# 795                        Timbalada               Agua mineral    0.970
# 801                          Tão Seu                      Skank    0.969
# 799                       Florentina                   Tiririca    0.966
# 822                  Preciso de você                    Netinho    0.960
# 788                    Tic, Tic, Tac                 Carrapicho    0.960
# 793              Rionegro e Solimões                Chora viola    0.932
# 784                       A namorada            Carlinhos Brown    0.931
# 805             Devagar, Devagarinho           Martinho da Vila    0.927
# 786                    La Bella Luna    Os Paralamas do Sucesso    0.927
# 769             recado a minha Amada                 Katinguelê    0.926
# 783                       SOS Brasil               Cidade Negra    0.920
# 790                 Me Dê Uma Chance          Cleiton & Camargo    0.919
# 773                        É o Tchan                 Gera Samba    0.900
# 821                          A Feira                    O Rappa    0.900
# 770                 À Primeira Vista            Daniela Mercury    0.891
# 823             Nas Ondas Do Partido           Fundo De Quintal    0.891
# 782                            Pinga                    Pato Fu    0.890
# 811                      Mama África                Chico César    0.885
# 796       O Samba Não Tem Fronteiras          Só Pra Contrariar    0.853
# 792                       Bom bocado                Art Popular    0.847
# 810                        É o bicho             Ricardo Chaves    0.845
# 820                   Bailão De Peão       Chitãozinho e Xororó    0.845
# 789                 Tô Pensando Nela             Gian & Giovani    0.844
# 814                      Ibiza Dance                 Roupa Nova    0.833
# 766                  Garota Nacional                      Skank    0.808
# 818                 Lourinha Bombril    Os Paralamas do Sucesso    0.800
# 785                A dança do Bumbum                  É o Tchan    0.794
# 775                Danca da cordinha                  É o tchan    0.793
# 774                      Beleza Rara                  Banda Eva    0.772
# 806                          Sozinho                 Raça Negra    0.770
# 817                       Firmamento               Cidade Negra    0.765
# 808                         Vermelho              Marcia Freire    0.743
# 798       Brasil é o País do Suingue             Fernanda Abreu    0.740
# 791           No Compasso do Criador                 Katinguelê    0.711
# 797                    Soul de Verão               Sandra de Sá    0.638
# 777            Minha estrela perdida        João Paulo e Daniel    0.631
# 768            Sem Medo de Ser Feliz  Zezé di Camargo e Luciano    0.607
# 824                         Tanajura           Negritude Junior    0.557
# 803         É Uma Partida De Futebol                      Skank    0.543
# 779  Felicidade, que saudade de você  Zezé Di Camargo & Luciano    0.524
# 772                      Indiferença  Zezé Di Camargo & Luciano    0.492
# 800                       Teu cafuné            Mauricio Mattar    0.477
# 804                Papel De Chiclete             Gian e Giovani    0.474
# 802        Eu Te Amo, Te Amo, Te Amo            Roberta Miranda    0.461
# 807              La forza della vita               Renato Russo    0.443
# 794                 Com qual carícia        João Paulo e Daniel    0.442
# 778                    Doce Mistério         Leandro e Leonardo    0.405
# 781                     Não vá ainda               Zélia Duncan    0.358
# 767                 Estou Apaixonado        João Paulo e Daniel    0.353
# 780                       Teu Charme                 Os Morenos    0.342
# 771                          Eu Juro         Leandro & Leonardo    0.280
# 809                 À Primeira Vista                Chico César    0.248
# 813                   Coração gelado               José Augusto    0.231
# 812                           Templo              Renata Arruda    0.103

# %%
ax = sns.boxplot(x="Ano", y="valence", data=df)

# %%
df.corr()
# Out:
#                    Posicao       Ano  danceability    energy       key  \
# Posicao           1.000000 -0.010277     -0.014478  0.003536  0.007301
# Ano              -0.010277  1.000000      0.222441  0.344342  0.022819
# danceability     -0.014478  0.222441      1.000000  0.232274  0.035654
# energy            0.003536  0.344342      0.232274  1.000000 -0.018003
# key               0.007301  0.022819      0.035654 -0.018003  1.000000
# loudness         -0.021814  0.586465      0.205160  0.735270 -0.008075
# mode             -0.012564 -0.021803     -0.142602 -0.051159 -0.134892
# speechiness      -0.012139  0.186753      0.118349  0.183656  0.036161
# acousticness     -0.000640 -0.038562     -0.196669 -0.453477  0.016499
# instrumentalness -0.000867 -0.062624      0.015156 -0.099667  0.019156
# liveness          0.000523  0.155571     -0.221945  0.287839 -0.015595
# valence           0.039885  0.064520      0.536313  0.498153  0.015630
# tempo            -0.046248  0.149934     -0.055368  0.238661 -0.031916
# duration_ms      -0.030527 -0.313208     -0.190190 -0.176030 -0.008251
# time_signature   -0.008067  0.064962      0.139636  0.119256 -0.011504
#
#                   loudness      mode  speechiness  acousticness  \
# Posicao          -0.021814 -0.012564    -0.012139     -0.000640
# Ano               0.586465 -0.021803     0.186753     -0.038562
# danceability      0.205160 -0.142602     0.118349     -0.196669
# energy            0.735270 -0.051159     0.183656     -0.453477
# key              -0.008075 -0.134892     0.036161      0.016499
# loudness          1.000000 -0.002205     0.140889     -0.281516
# mode             -0.002205  1.000000    -0.096777      0.046130
# speechiness       0.140889 -0.096777     1.000000     -0.069335
# acousticness     -0.281516  0.046130    -0.069335      1.000000
# instrumentalness -0.174946 -0.012017    -0.002983     -0.048453
# liveness          0.200193  0.062925     0.051512      0.057241
# valence           0.230338 -0.120551     0.162908     -0.271738
# tempo             0.189042 -0.014193     0.101288     -0.100049
# duration_ms      -0.217360 -0.007435    -0.147300      0.009352
# time_signature    0.069042 -0.044773     0.069373     -0.120816
#
#                   instrumentalness  liveness   valence     tempo  duration_ms  \
# Posicao                  -0.000867  0.000523  0.039885 -0.046248    -0.030527
# Ano                      -0.062624  0.155571  0.064520  0.149934    -0.313208
# danceability              0.015156 -0.221945  0.536313 -0.055368    -0.190190
# energy                   -0.099667  0.287839  0.498153  0.238661    -0.176030
# key                       0.019156 -0.015595  0.015630 -0.031916    -0.008251
# loudness                 -0.174946  0.200193  0.230338  0.189042    -0.217360
# mode                     -0.012017  0.062925 -0.120551 -0.014193    -0.007435
# speechiness              -0.002983  0.051512  0.162908  0.101288    -0.147300
# acousticness             -0.048453  0.057241 -0.271738 -0.100049     0.009352
# instrumentalness          1.000000 -0.048879 -0.045845 -0.011454     0.010522
# liveness                 -0.048879  1.000000 -0.075677  0.032025    -0.019876
# valence                  -0.045845 -0.075677  1.000000  0.150139    -0.180958
# tempo                    -0.011454  0.032025  0.150139  1.000000    -0.135739
# duration_ms               0.010522 -0.019876 -0.180958 -0.135739     1.000000
# time_signature           -0.005599  0.013408  0.108680 -0.009851     0.019625
#
#                   time_signature
# Posicao                -0.008067
# Ano                     0.064962
# danceability            0.139636
# energy                  0.119256
# key                    -0.011504
# loudness                0.069042
# mode                   -0.044773
# speechiness             0.069373
# acousticness           -0.120816
# instrumentalness       -0.005599
# liveness                0.013408
# valence                 0.108680
# tempo                  -0.009851
# duration_ms             0.019625
# time_signature          1.000000

# %%
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, cmap='RdBu')
